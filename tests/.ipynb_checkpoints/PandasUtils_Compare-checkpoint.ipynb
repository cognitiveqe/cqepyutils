# %%
from PandasUtils import PandasUtils as cpd
import pandas as pd
import time

# %%
actual_file_path = r'C://Desktop//Comparison//data//actual//'
expected_file_path = r'C://Desktop//Comparison//data//baseline//'

# %%
expected_file_name = '100_Sales_Records'
actual_file_name = '100_Sales_Records_1'
file_format = 'csv'
key_columns = ['Region', 'Country', 'Item_Type', 'Sales_Channel', 'Order_Priority', 'Order_Date']
# key_columns = ['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority', 'Order Date']
ignore_columns = ['Unit_Price', 'Total_Revenue']

# %%
start = time.time()
exec_summary_df, dup_cons_df, key_matched_df, key_mismatch_df, cell_cmp_df = cpd.df_diff(actual_file_path, expected_file_path,
                                                                        actual_file_name, expected_file_name,
                                                                        file_format, key_columns, ignore_columns)
print(str((time.time() - start)))
print(str((time.time() - start)/60))
# Out:
# ****************************************************************************************************
# PandasUtil Data Frame Comparison - Cell by Cell comparison with detailed mismatch report
# ****************************************************************************************************
# Step-01 : Based on file format create the data frames with delimiter(sep)
# Step-02 : Remove the columns based on ignore columns list
# Step-03 : Check for duplicate rows in both actual and expected
# Step-04 : Remove duplicate records from actual and expected
# Step-05 : Sort the actual and expected based on key columns and reset the index
# Step-06 : Identify the rows matching based on key in both actual and expected
# Step-07 : Create the summary report based on count diff, duplicate rows and key mismatches
# Step-08 : Remove the mismatched key values and proceed further in validation
# Step-09 : Started cell by cell comparison for key values that exist in both actual and expected
# ...

# %%
exec_summary_df
# Out:
#          Summary Expected Actual Mismatch
# 0  Total_Records       89    100      -11
# 1     Duplicates        0     10        0
# 2   Key_Mismatch        9     10        0

# %%
dup_cons_df
# Out:
#                          Region           Country        Item_Type  \
# 0                          Asia         Sri Lanka           Fruits
# 1         Australia and Oceania  Papua New Guinea             Meat
# 2                        Europe          Slovakia        Beverages
# 3  Middle East and North Africa           Morocco          Clothes
# 4            Sub-Saharan Africa          Djibouti          Clothes
# 5            Sub-Saharan Africa             Ghana  Office Supplies
# 6            Sub-Saharan Africa       Seychelles         Beverages
# 7            Sub-Saharan Africa      South Africa           Fruits
# 8            Sub-Saharan Africa          Tanzania        Beverages
# 9            Sub-Saharan Africa          Tanzania        Cosmetics
#
#   Sales_Channel Order_Priority Order_Date   Order_ID Ship_Date Units_Sold  \
# 0        Online              L    11/7/11  830192887  12/18/11          0
# 1       Offline              M    5/15/15  940995585    6/4/15          0
# ...

# %%
len(key_matched_df)
# Out:
# 80

# %%
key_matched_df
# Out:
#                                                                                       Order_ID_x  \
# Region             Country    Item_Type       Sales_Channel Order_Priority Order_Date
# Asia               Brunei     Cereal          Offline       L              5/28/13     153842341
#                    India      Snacks          Online        L              10/10/12    440306556
#                    Indonesia  Household       Online        C              9/28/11     520480573
#                               Personal Care   Offline       L              10/22/12    678896129
#                    Japan      Household       Offline       M              7/16/14     747796285
# ...                                                                                          ...
# Sub-Saharan Africa Tanzania   Fruits          Offline       H              10/20/14    156530129
#                    The Gambia Fruits          Online        C              11/20/11    862861335
# ...

# %%
key_mismatch_df
# Out:
#                                                                                                                                 source
# Region                            Country                          Item_Type       Sales_Channel Order_Priority Order_Date
# Asia                              Turkmenistan                     Meat            Online        M              4/30/17      left_only
# Australia and Oceania             New Zealand                      Beverages       Online        M              10/11/12     left_only
#                                   Vanuatu                          Cereal          Offline       C              6/20/14      left_only
# Middle East and North Africa      Pakistan                         Meat            Online        M              12/28/13     left_only
# North America                     United States of America         Personal Care   Online        H              1/21/16      left_only
# ...

# %%
cell_cmp_df
# Out:
#                                                                                  Expected_Data  \
# Region Country Item_Type Sales_Channel Order_Priority Order_Date Mismatch_Column
# Asia   Brunei  Cereal    Offline       L              5/28/13    Unit_Cost              117.11
#
#                                                                                  Actual_Data
# Region Country Item_Type Sales_Channel Order_Priority Order_Date Mismatch_Column
# Asia   Brunei  Cereal    Offline       L              5/28/13    Unit_Cost            127.11
